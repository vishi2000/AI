# %% [markdown]
# <a href="https://colab.research.google.com/github/vishi2000/AI/blob/main/Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.random.seed(1)
# function to select random values

# %%
# picks 1000 random ints btw 0 to 50
x = np.random.randint(0,50,100)

# %%
x
# Out:
# array([37, 43, 12,  8,  9, 11,  5, 15,  0, 16,  1, 12,  7, 45,  6, 25, 20,
#        37, 18, 20, 11, 42, 28, 29, 14,  4, 23, 23, 41, 49, 30, 32, 22, 13,
#        41,  9,  7, 22,  1,  0, 17,  8, 24, 13, 47, 42,  8, 30,  7,  3,  6,
#        21, 49,  3,  4, 24, 49, 43, 12, 26, 16, 45, 41, 18, 15,  0,  4, 25,
#        47, 34, 23,  7, 26, 25, 40, 22,  9,  3, 39, 23, 36, 27, 37, 19, 38,
#         8, 32, 34, 10, 23, 15, 47, 23, 25,  7, 28, 10, 46, 32, 24])

# %%
#positive corelation with same noise
y = x + np.random.normal(0,10,100)

# %%
y
# Out:
# array([ 41.98901154,  51.59827041,  23.07419601,   9.68813844,
#          0.40056558,  19.95994944,   3.33049456,  37.53890892,
#          4.13795281,  25.74208593, -15.19968428,  18.3472439 ,
#         22.58983498,  45.09367296,   1.17598249,  33.49752525,
#         41.77380967,  34.72494969,  13.61873797,  11.96722154,
#         -6.41927724,  43.1380381 ,  27.94453981,  39.45966796,
#         21.24390609,   0.94309423,  28.46687344,  17.94514942,
#         41.83497957,  61.41105051,  10.88242245,  43.73128419,
#         13.06431696,  16.38288119,  23.63954384,  -2.27990617,
#          7.71124761,  21.30397425,  -1.23381681, -12.28269715,
#         -7.57432683,   2.74877454,  27.69591287,   8.20784193,
#         50.20387902,  29.6378688 ,  -3.96291654,  28.35319865,
#         17.40301664,  -4.71152364,  20.42239809,  29.67152725,
#         45.42551992,  10.53297054,   9.08989092,  25.16823363,
#         35.92320035,  39.37902327,  16.07148403,  15.10510762,
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.82555743],
#        [0.82555743, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
#negative corelation with same noise
y = 100 - x + np.random.normal(0,10,100)
np.corrcoef(x,y)
# Out:
# array([[ 1.       , -0.7914486],
#        [-0.7914486,  1.       ]])

# %%
plt.scatter(x,y)
plt.show()

# %%
x = np.random.normal(0,10,100)
y = np.random.normal(0,10,100)

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.07352283],
#        [-0.07352283,  1.        ]])

# %%
# Correlation matrix
import pandas as pd

# %%
df = pd.DataFrame({'a' : np.random.randint(0,50,1000)})
df['b']=df['a'] + np.random.randint(0,10,1000)
df['c']= 100 - df['a'] + np.random.randint(0,10,1000)
df['d']= np.random.randint(0,50,1000)
df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.979837 -0.980875 -0.002099
# b  0.979837  1.000000 -0.960714 -0.001695
# c -0.980875 -0.960714  1.000000  0.003462
# d -0.002099 -0.001695  0.003462  1.000000

# %%
pd.plotting.scatter_matrix(df,figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()
